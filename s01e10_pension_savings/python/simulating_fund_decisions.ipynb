# %% [markdown]
# # Simulation of investment decisions
#
# The following notebook analyzes various fund investment decisions.
#
# The main goal of this analysis is to see the performance of the best fund in the "stock oriented" funds compared to a random selection (out of the funds in that specific group).

# %%
# Import required libraries
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# Read the data file
investments_raw = pd.read_csv("../data/all_gemel_data_raw.csv")

# glimpse on the head of the data
investments_raw.head()
# Out:
#    FUND_ID                                          FUND_NAME  \
# 0    12535  "אינטרגמל השתלמות" קרן השתלמות לשכירים ולעצמאי...
# 1    12536  "אינטרגמל השתלמות" קרן השתלמות לשכירים ולעצמאי...
# 2     9676  "אינטרגמל השתלמות" קרן השתלמות לשכירים ולעצמאי...
# 3     9676  "אינטרגמל השתלמות" קרן השתלמות לשכירים ולעצמאי...
# 4     9676  "אינטרגמל השתלמות" קרן השתלמות לשכירים ולעצמאי...
#
#   FUND_CLASSIFICATION CONTROLLING_CORPORATION     MANAGING_CORPORATION  \
# 0       קרנות השתלמות     י.ד מור השקעות בע"מ       מור קופות גמל בע"מ
# 1       קרנות השתלמות     י.ד מור השקעות בע"מ       מור קופות גמל בע"מ
# 2       קרנות השתלמות    אס.או.אי אחזקות בע"מ  אינטרגמל קופות גמל בע"מ
# 3       קרנות השתלמות    אס.או.אי אחזקות בע"מ  אינטרגמל קופות גמל בע"מ
# 4       קרנות השתלמות    אס.או.אי אחזקות בע"מ  אינטרגמל קופות גמל בע"מ
#
#    REPORT_PERIOD INCEPTION_DATE TARGET_POPULATION SPECIALIZATION  \
# 0       201812.0     26/12/2018     כלל האוכלוסיה           כללי
# 1       201812.0     26/12/2018     כלל האוכלוסיה          מניות
# 2       201510.0     14/10/2015     כלל האוכלוסיה           כללי
# 3       201511.0     14/10/2015     כלל האוכלוסיה           כללי
# 4       201512.0     14/10/2015     כלל האוכלוסיה           כללי
#
#   SUB_SPECIALIZATION  ...  STANDARD_DEVIATION  ALPHA  SHARPE_RATIO  \
# 0               כללי  ...                 NaN    NaN           NaN
# 1              מניות  ...                 NaN    NaN           NaN
# 2               כללי  ...                 NaN    NaN           NaN
# 3               כללי  ...                 NaN    NaN           NaN
# 4               כללי  ...                 NaN    NaN           NaN
#
#    LIQUID_ASSETS_PERCENT  STOCK_MARKET_EXPOSURE  FOREIGN_EXPOSURE  \
# 0                   93.4                   0.05              0.02
# 1                   93.7                   0.12              0.05
# 2                    NaN                    NaN               NaN
# 3                    NaN                   0.02              0.00
# 4                   99.2                   0.03              0.00
#
#    FOREIGN_CURRENCY_EXPOSURE  MANAGING_CORPORATION_LEGAL_ID  \
# 0                       0.02                    514956465.0
# 1                       0.05                    514956465.0
# 2                        NaN                    514956465.0
# 3                       0.00                    514956465.0
# 4                       0.00                    514956465.0
#
#           CURRENT_DATE   ...33
# 0           29/05/2019     NaN
# 1           29/05/2019     NaN
# 2  10/07/2018 08:31:02  7137.0
# 3  10/07/2018 08:31:02  7138.0
# 4  10/07/2018 08:31:02  7139.0
#
# [5 rows x 33 columns]

# %%
# show the columns
investments_raw.columns
# Out:
# Index(['FUND_ID', 'FUND_NAME', 'FUND_CLASSIFICATION',
#        'CONTROLLING_CORPORATION', 'MANAGING_CORPORATION', 'REPORT_PERIOD',
#        'INCEPTION_DATE', 'TARGET_POPULATION', 'SPECIALIZATION',
#        'SUB_SPECIALIZATION', 'DEPOSITS', 'WITHDRAWLS', 'INTERNAL_TRANSFERS',
#        'NET_MONTHLY_DEPOSITS', 'TOTAL_ASSETS', 'AVG_ANNUAL_MANAGEMENT_FEE',
#        'AVG_DEPOSIT_FEE', 'MONTHLY_YIELD', 'YEAR_TO_DATE_YIELD',
#        'YIELD_TRAILING_3_YRS', 'YIELD_TRAILING_5_YRS',
#        'AVG_ANNUAL_YIELD_TRAILING_3YRS', 'AVG_ANNUAL_YIELD_TRAILING_5YRS',
#        'STANDARD_DEVIATION', 'ALPHA', 'SHARPE_RATIO', 'LIQUID_ASSETS_PERCENT',
#        'STOCK_MARKET_EXPOSURE', 'FOREIGN_EXPOSURE',
#        'FOREIGN_CURRENCY_EXPOSURE', 'MANAGING_CORPORATION_LEGAL_ID',
#        'CURRENT_DATE', '...33'],
#       dtype='object')

# %% [markdown]
# We're going to focus on the specific tool called "קרנות השתלמות" (i.e., FUND_CLASSIFICATION == "קרנות השתלמות"), and within it, just the funds which invest mostly in stocks (SPECIALIZATION == "מניות" and SUB_SPECIALIZATION == "מניות").

# %%
# filter to funds with stock specialization
stock_specialization = investments_raw[investments_raw.SPECIALIZATION == "מניות"]
stock_specialization = stock_specialization[stock_specialization.FUND_CLASSIFICATION == "קרנות השתלמות"]
stock_specialization = stock_specialization[stock_specialization.SUB_SPECIALIZATION == "מניות"]
stock_specialization
# Out:
#        FUND_ID                                          FUND_NAME  \
# 1        12536  "אינטרגמל השתלמות" קרן השתלמות לשכירים ולעצמאי...
# 798       1446                      אומגה קרן השתלמות מסלול מניות
# 799       1446                      אומגה קרן השתלמות מסלול מניות
# 800       1446                      אומגה קרן השתלמות מסלול מניות
# 801       1446                      אומגה קרן השתלמות מסלול מניות
# ...        ...                                                ...
# 91660     1015             תמיר פישמן השתלמות מניות בישראל ובחו"ל
# 91661     1015             תמיר פישמן השתלמות מניות בישראל ובחו"ל
# 91662     1015             תמיר פישמן השתלמות מניות בישראל ובחו"ל
# 91663     1015             תמיר פישמן השתלמות מניות בישראל ובחו"ל
# 91664     1015             תמיר פישמן השתלמות מניות בישראל ובחו"ל
#
#       FUND_CLASSIFICATION   CONTROLLING_CORPORATION  \
# 1           קרנות השתלמות       י.ד מור השקעות בע"מ
# 798         קרנות השתלמות  מנורה מבטחים החזקות בע"מ
# 799         קרנות השתלמות  מנורה מבטחים החזקות בע"מ
# 800         קרנות השתלמות  מנורה מבטחים החזקות בע"מ
# 801         קרנות השתלמות  מנורה מבטחים החזקות בע"מ
# ...                   ...                       ...
# 91660       קרנות השתלמות                       אחר
# 91661       קרנות השתלמות                       אחר
# 91662       קרנות השתלמות                       אחר
# 91663       קרנות השתלמות                       אחר
# 91664       קרנות השתלמות                       אחר
#
#                                     MANAGING_CORPORATION  REPORT_PERIOD  \
# 1                                     מור קופות גמל בע"מ       201812.0
# 798    מנורה מבטחים והסתדרות המהנדסים ניהול קופות גמל...       201312.0
# 799    מנורה מבטחים והסתדרות המהנדסים ניהול קופות גמל...       201401.0
# 800    מנורה מבטחים והסתדרות המהנדסים ניהול קופות גמל...       201402.0
# 801    מנורה מבטחים והסתדרות המהנדסים ניהול קופות גמל...       201403.0
# ...                                                  ...            ...
# 91660                       תמיר פישמן גמל והשתלמות בע"מ       201210.0
# 91661                       תמיר פישמן גמל והשתלמות בע"מ       201211.0
# 91662                       תמיר פישמן גמל והשתלמות בע"מ       201212.0
# 91663                       תמיר פישמן גמל והשתלמות בע"מ       201301.0
# 91664                       תמיר פישמן גמל והשתלמות בע"מ       201302.0
#
#       INCEPTION_DATE   TARGET_POPULATION SPECIALIZATION SUB_SPECIALIZATION  \
# 1         26/12/2018       כלל האוכלוסיה          מניות              מניות
# 798       03/02/2009  עובדי סקטור מסויים          מניות              מניות
# 799       03/02/2009  עובדי סקטור מסויים          מניות              מניות
# 800       03/02/2009  עובדי סקטור מסויים          מניות              מניות
# 801       03/02/2009  עובדי סקטור מסויים          מניות              מניות
# ...              ...                 ...            ...                ...
# 91660     29/07/2004       כלל האוכלוסיה          מניות              מניות
# 91661     29/07/2004       כלל האוכלוסיה          מניות              מניות
# 91662     29/07/2004       כלל האוכלוסיה          מניות              מניות
# 91663     29/07/2004       כלל האוכלוסיה          מניות              מניות
# 91664     29/07/2004       כלל האוכלוסיה          מניות              מניות
#
#        ...  STANDARD_DEVIATION  ALPHA  SHARPE_RATIO  LIQUID_ASSETS_PERCENT  \
# 1      ...                 NaN    NaN           NaN                   93.7
# 798    ...                 NaN    NaN           NaN                   94.1
# 799    ...                 NaN    NaN           NaN                   93.8
# 800    ...                 NaN    NaN           NaN                   93.9
# 801    ...                 NaN    NaN           NaN                   93.6
# ...    ...                 ...    ...           ...                    ...
# 91660  ...               19.30  -4.20         -0.14                   87.6
# 91661  ...               19.14  -3.96         -0.08                   87.4
# 91662  ...               19.14  -3.00         -0.08                   87.8
# 91663  ...               18.54  -2.40          0.02                   87.0
# 91664  ...               18.53  -2.76          0.04                   86.4
#
#        STOCK_MARKET_EXPOSURE  FOREIGN_EXPOSURE  FOREIGN_CURRENCY_EXPOSURE  \
# 1                       0.12              0.05                       0.05
# 798                     7.75              3.30                       3.31
# 799                     7.67              3.21                       3.22
# 800                     7.99              3.36                       3.37
# 801                     7.85              3.14                       3.15
# ...                      ...               ...                        ...
# 91660                  14.86              6.94                       7.12
# 91661                  15.36              7.58                       7.78
# 91662                  15.97              7.86                       8.07
# 91663                  16.02              8.17                       8.40
# 91664                  15.08              8.12                       8.35
#
#        MANAGING_CORPORATION_LEGAL_ID         CURRENT_DATE   ...33
# 1                        514956465.0           29/05/2019     NaN
# 798                      520027715.0  10/07/2018 08:29:21  5656.0
# 799                      520027715.0  10/07/2018 08:30:12  4713.0
# 800                      520027715.0  10/07/2018 08:30:12  4714.0
# 801                      520027715.0  10/07/2018 08:30:12  4715.0
# ...                              ...                  ...     ...
# 91660                    513571273.0  10/07/2018 08:28:19  3055.0
# 91661                    513571273.0  10/07/2018 08:28:19  3056.0
# 91662                    513571273.0  10/07/2018 08:28:19  3057.0
# 91663                    513571273.0  10/07/2018 08:29:21  3286.0
# 91664                    513571273.0  10/07/2018 08:29:21  3287.0
#
# [3447 rows x 33 columns]

# %% [markdown]
# I want to verify the minimum date for each of the funds, and the number of observations for each fund.

# %%
# Number of observations per fund
obs_per_fund = (stock_specialization
   .groupby("FUND_NAME")
   .size()
   .sort_values(ascending=False))

obs_per_fund
# Out:
# FUND_NAME
# אקסלנס השתלמות מניות                                                200
# מנורה מבטחים השתלמות מסלול מניות                                    176
# מיטב דש השתלמות מניות                                               142
# רום קרן השתלמות לעובדי הרשויות המקומיות מסלול ספיר מניות            142
# קרן השתלמות להנדסאים וטכנאים - מסלול מניות                          142
# קרן החיסכון לצבא הקבע מניות                                         142
# כלל השתלמות מניות                                                   142
# קרן השתלמות למשפטנים מסלול מנייתי                                   142
# קרן השתלמות לאקדמאים במדעי החברה והרוח מסלול מניות                  142
# מינהל - קרן ההשתלמות לפקידים עובדי המינהל והשרותים - מסלול מניות    142
# רעות קרן השתלמות - מניות                                            142
# אנליסט השתלמות מניות                                                142
# הלמן-אלדובי השתלמות מניות                                           130
# פסגות שיא השתלמות מניות                                             130
# אלטשולר שחם השתלמות מניות                                           125
# מגדל השתלמות מסלול מניות                                            121
# אומגה קרן השתלמות מסלול מניות                                       107
# ילין לפידות קרן השתלמות מסלול מניות                                 100
# אי.בי.אי קרן השתלמות מסלול מניות                                     96
# הראל השתלמות מסלול מניות                                             94
# ק.ס.מ. קרן השתלמות לביוכימאים ומקרוביולוגים בע"מ מניות               81
# עובדי מדינה - מסלול מניות                                            81
# השתלמות רופאים מניות                                                 55
# השתלמות שיטת הפניקס סל עוקב מדד ת"א 100                              48
# מור השתלמות קרן השתלמות לשכירים ולעצמאים  מניות                      46
# קל השתלמות מניות מניות                                               43
# מיטב השתלמות חכם מסלול מנייתי                                        42
# איילון השתלמות מסלול מניות                                           42
# אקסלנס השתלמות זהב - מסלול מניות                                     36
# פסגות השתלמות מניות                                                  36
# מיטב השתלמות מניות                                                   33
# הדס ארזים אפסילון השתלמות מסלול מנייתי                               33
# איפקס השתלמות מניות                                                  30
# תמיר פישמן השתלמות מניות בישראל ובחו"ל                               26
# סלייס השתלמות מניות מניות                                            22
# הפניקס השתלמות מניות                                                 22
# נירית מניות                                                          16
# מיטב דינאמית להשתלמות מסלול מניות                                    15
# פסגות שיא השתלמות מנייתי                                             13
# דש אקונומיסט השתלמות מניות                                           12
# דש השתלמות מניות                                                      9
# מילניום קרן השתלמות מסלולית - מסלול מניות                             3
# מיטב וויזר השתלמות מניות                                              3
# "אינטרגמל השתלמות" קרן השתלמות לשכירים ולעצמאים  מניות מניות          1
# dtype: int64

# %% [markdown]
# Let's check the minimum, maximum, and number of observations per each fund, and try to understand why the number of observations varies so signficantly.

# %%
min_max_date_per_fund = (stock_specialization[["FUND_NAME", "REPORT_PERIOD"]]
   .groupby("FUND_NAME")
   .agg(['min', 'max', "size"])
   .reset_index())

min_max_date_per_fund.columns = ['_'.join(col).strip() for col in min_max_date_per_fund.columns.values]

min_max_date_per_fund
# Out:
#                                            FUND_NAME_  REPORT_PERIOD_min  \
# 0   "אינטרגמל השתלמות" קרן השתלמות לשכירים ולעצמאי...           201812.0
# 1                       אומגה קרן השתלמות מסלול מניות           201312.0
# 2                    אי.בי.אי קרן השתלמות מסלול מניות           201101.0
# 3                          איילון השתלמות מסלול מניות           201308.0
# 4                                 איפקס השתלמות מניות           201201.0
# 5                           אלטשולר שחם השתלמות מניות           201206.0
# 6                                אנליסט השתלמות מניות           201101.0
# 7                    אקסלנס השתלמות זהב - מסלול מניות           201101.0
# 8                                אקסלנס השתלמות מניות           201101.0
# 9                          דש אקונומיסט השתלמות מניות           201307.0
# 10                                   דש השתלמות מניות           201307.0
# 11             הדס ארזים אפסילון השתלמות מסלול מנייתי           201101.0
# 12                          הלמן-אלדובי השתלמות מניות           201101.0
# 13                               הפניקס השתלמות מניות           202101.0
# 14                           הראל השתלמות מסלול מניות           201501.0
# 15                               השתלמות רופאים מניות           201804.0
# 16            השתלמות שיטת הפניקס סל עוקב מדד ת"א 100           201208.0
# 17                ילין לפידות קרן השתלמות מסלול מניות           201407.0
# 18                                  כלל השתלמות מניות           201101.0
# 19                           מגדל השתלמות מסלול מניות           201210.0
# 20    מור השתלמות קרן השתלמות לשכירים ולעצמאים  מניות           201901.0
# 21                  מיטב דינאמית להשתלמות מסלול מניות           201101.0
# 22                              מיטב דש השתלמות מניות           201101.0
# 23                      מיטב השתלמות חכם מסלול מנייתי           201101.0
# 24                                 מיטב השתלמות מניות           201101.0
# 25                           מיטב וויזר השתלמות מניות           201101.0
# 26          מילניום קרן השתלמות מסלולית - מסלול מניות           201101.0
# 27  מינהל - קרן ההשתלמות לפקידים עובדי המינהל והשר...           201101.0
# 28                   מנורה מבטחים השתלמות מסלול מניות           201101.0
# 29                                        נירית מניות           201206.0
# 30                          סלייס השתלמות מניות מניות           202101.0
# 31                          עובדי מדינה - מסלול מניות           201602.0
# 32                                פסגות השתלמות מניות           201101.0
# 33                            פסגות שיא השתלמות מניות           201101.0
# 34                           פסגות שיא השתלמות מנייתי           201101.0
# 35  ק.ס.מ. קרן השתלמות לביוכימאים ומקרוביולוגים בע...           201602.0
# 36                             קל השתלמות מניות מניות           201706.0
# 37                        קרן החיסכון לצבא הקבע מניות           201101.0
# 38  קרן השתלמות לאקדמאים במדעי החברה והרוח מסלול מ...           201101.0
# 39         קרן השתלמות להנדסאים וטכנאים - מסלול מניות           201101.0
# 40                  קרן השתלמות למשפטנים מסלול מנייתי           201101.0
# 41  רום קרן השתלמות לעובדי הרשויות המקומיות מסלול ...           201101.0
# 42                           רעות קרן השתלמות - מניות           201101.0
# 43             תמיר פישמן השתלמות מניות בישראל ובחו"ל           201101.0
#
#     REPORT_PERIOD_max  REPORT_PERIOD_size
# 0            201812.0                   1
# 1            202210.0                 107
# 2            201812.0                  96
# 3            201701.0                  42
# 4            201406.0                  30
# 5            202210.0                 125
# 6            202210.0                 142
# 7            201312.0                  36
# 8            202012.0                 200
# 9            201406.0                  12
# 10           201403.0                   9
# 11           201309.0                  33
# 12           202110.0                 130
# 13           202210.0                  22
# 14           202210.0                  94
# 15           202210.0                  55
# 16           201607.0                  48
# 17           202210.0                 100
# 18           202210.0                 142
# 19           202210.0                 121
# 20           202210.0                  46
# 21           201203.0                  15
# 22           202210.0                 142
# 23           201406.0                  42
# 24           201309.0                  33
# 25           201103.0                   3
# 26           201103.0                   3
# 27           202210.0                 142
# 28           202210.0                 176
# 29           201309.0                  16
# 30           202210.0                  22
# 31           202210.0                  81
# 32           201312.0                  36
# 33           202110.0                 130
# 34           201208.0                  13
# 35           202210.0                  81
# 36           202012.0                  43
# 37           202210.0                 142
# 38           202210.0                 142
# 39           202210.0                 142
# 40           202210.0                 142
# 41           202210.0                 142
# 42           202210.0                 142
# 43           201302.0                  26

# %% [markdown]
# The number of observations varies significantly.
# It seems that in order to increase the sample size we should not start from 2011 but maybe from 2015 (this will help add some funds).
# Also, verify why there are two funds with too many observations (duplicates?): אקסלנס השתלמות מניות (n=200) and מנורה מבטחים השתלמות מניות (n=176) versus the rest with history from 2011 (n=142, i.e., 12 years * 12 months - 2 months since we end on October's data).
#
# In addition, the subclassification doesn't seem to change over time.

# %%
# Is subclassification consistnet?
check_consistent_subclass = (investments_raw
   .query('SPECIALIZATION == "מניות"')
   .query('FUND_CLASSIFICATION == "קרנות השתלמות"')
   .filter(items = ["FUND_NAME", "SUB_SPECIALIZATION"])
   .groupby("FUND_NAME")
   .nunique("SUB_SPECIALIZATION")
   .sort_values(by = "SUB_SPECIALIZATION")
   .reset_index()
)

check_consistent_subclass
# Out:
#                                             FUND_NAME  SUB_SPECIALIZATION
# 0   "אינטרגמל השתלמות" קרן השתלמות לשכירים ולעצמאי...                   1
# 1                מנורה מבטחים השתלמות מחקה מדד S&P500                   1
# 2   מינהל - קרן ההשתלמות לפקידים עובדי המינהל והשר...                   1
# 3           מילניום קרן השתלמות מסלולית - מסלול מניות                   1
# 4                            מיטב וויזר השתלמות מניות                   1
# ..                                                ...                 ...
# 66             הדס ארזים אפסילון השתלמות מסלול מנייתי                   1
# 67                                   דש השתלמות מניות                   1
# 68                         דש אקונומיסט השתלמות מניות                   1
# 69  הלמן-אלדובי קרן השתלמות מסלול פאסיבי - מדדי מנ...                   1
# 70                      תמיר פישמן השתלמות מניות חו"ל                   1
#
# [71 rows x 2 columns]

# %% [markdown]
# Extract the fund names we will work on from now on.

# %%
min_date_check = 201500
expected_months = (round(202310/100) - round(min_date_check/100))*12 - 2

use_funds_pre = (stock_specialization
   .filter(items = ["FUND_NAME", "REPORT_PERIOD"])
   .query(f"REPORT_PERIOD >= {min_date_check}")
   .groupby("FUND_NAME")
   .agg(['min', 'max', "size"])
   .reset_index())

use_funds_pre.columns = [''.join(col).strip() for col in min_max_date_per_fund.columns.values]

use_funds = (use_funds_pre
   .rename(columns = {"FUND_NAME_" : "FUND_NAME"})
   .query("REPORT_PERIOD_max == 202210")
   .query(f"REPORT_PERIOD_min >= {min_date_check}")
   .query(f"REPORT_PERIOD_size == {expected_months}"))

print(use_funds["FUND_NAME"].count())

fund_name_list = list(use_funds["FUND_NAME"])

fund_name_list
# Out:
# 16
# ['אומגה קרן השתלמות מסלול מניות',
#  'אלטשולר שחם השתלמות מניות',
#  'אנליסט השתלמות מניות',
#  'הראל השתלמות מסלול מניות',
#  'ילין לפידות קרן השתלמות מסלול מניות',
#  'כלל השתלמות מניות',
#  'מגדל השתלמות מסלול מניות',
#  'מיטב דש השתלמות מניות',
#  'מינהל - קרן ההשתלמות לפקידים עובדי המינהל והשרותים - מסלול מניות',
#  'מנורה מבטחים השתלמות מסלול מניות',
#  'קרן החיסכון לצבא הקבע מניות',
#  'קרן השתלמות לאקדמאים במדעי החברה והרוח מסלול מניות',
#  'קרן השתלמות להנדסאים וטכנאים - מסלול מניות',
#  'קרן השתלמות למשפטנים מסלול מנייתי',
#  'רום קרן השתלמות לעובדי הרשויות המקומיות מסלול ספיר מניות',
#  'רעות קרן השתלמות - מניות']

# %% [markdown]
# The analysis shows that choosing stock funds which started at 2015 and have statistics up until October 2022, yields 16 funds that we can work with.
#
# We will now define a function that given a start date and an end date computes the yield of all of the funds, returns the best fund's yield, the best fund's name, and the overall average.
